# %%
import matplotlib.pyplot as plt

# %%
import numpy as np

# %%
x =np.arange(0,10,0.1)

# %%
y= np.sin(x)

# %%
plt.plot(x,y)

# %%
plt.title("sinüs grafiği")
# Out:
# Text(0.5, 1.0, 'sinüs grafiği')

# %%
plt.xlabel(" x ekseni")
plt.ylabel("Y ekseni")
# Out:
# Text(0, 0.5, 'Y ekseni')

# %%
plt.plot(x,y)

# %%
plt.show()

# %%
x = np.random.ran(50)
y= np.random.rand(50)
colors=np.random.rand(50)
sizes=np.random.randint(50,150,50)

plt.scatter(x,y, c=colors, s=sizes)
plt.title("nokta grafiği")
plt.xlabel("x ekseni")
plt.ylabel("y ekseni")

plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_7928\2523067569.py in <module>
# ----> 1 x = np.random.ran(50)
#       2 y= np.random.rand(50)
#       3 colors=np.random.rand(50)
#       4 sizes=np.random.randint(50,150,50)
#       5
#
# AttributeError: module 'numpy.random' has no attribute 'ran'

# %%
x = np.random.ran(50)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_7928\179396060.py in <module>
# ----> 1 x = np.random.ran(50)
#
# AttributeError: module 'numpy.random' has no attribute 'ran'

# %%
x = np.random.rand(50)
y= np.random.rand(50)
colors=np.random.rand(50)
sizes=np.random.randint(50,150,50)

plt.scatter(x,y, c=colors, s=sizes)
plt.title("nokta grafiği")
plt.xlabel("x ekseni")
plt.ylabel("y ekseni")

plt.show()

# %%
data = np.random.randn(1000)
plt.hist(data,bins=30)
# Out:
# (array([ 3.,  2.,  3.,  2.,  6., 11., 18., 37., 33., 46., 51., 71., 93.,
#         90., 83., 73., 75., 60., 57., 53., 49., 29., 17., 15.,  8.,  7.,
#          5.,  1.,  1.,  1.]),
#  array([-3.1201437 , -2.90318526, -2.68622683, -2.46926839, -2.25230995,
#         -2.03535152, -1.81839308, -1.60143465, -1.38447621, -1.16751778,
#         -0.95055934, -0.73360091, -0.51664247, -0.29968404, -0.0827256 ,
#          0.13423284,  0.35119127,  0.56814971,  0.78510814,  1.00206658,
#          1.21902501,  1.43598345,  1.65294188,  1.86990032,  2.08685875,
#          2.30381719,  2.52077563,  2.73773406,  2.9546925 ,  3.17165093,
#          3.38860937]),
#  <BarContainer object of 30 artists>)

# %%
data = np.random.randn(1000)
plt.hist(data,bins=30)

plt.title("histogram")
plt.xlabel("değerler")
plt.ylabel("frequency")

plt.show()

# %%
x = ['A','B','C','D','E']
y=np.random.randint(1,10,5)

plt.bar(x,y)

plt.title("sinüs grafiği")
plt.xlabel("kategoriler")
plt.ylabel("değerler")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
sizes = [30,25,20,15,10,5,5]

plt.pie(sizes)

plt.title("pasta grafiği")

plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
